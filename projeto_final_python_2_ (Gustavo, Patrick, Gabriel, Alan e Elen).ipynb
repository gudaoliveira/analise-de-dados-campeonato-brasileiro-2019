# %% [markdown]
# <div style="text-align: center; font-size: 30px; font-weight:bold">
# ANÁLISE ESTATÍSTICA - A INFLUÊNCIA DA LONGEVIDADE DE UM TÉCNICO EM UM TIME NO BRASILEIRÃO DE 2019
# <br>
# "Lógica de programação 2 com Python" - ADA Tech & IFood 🎲

# %% [markdown]
# ## Integrantes: 👥
#
# -   #### Alan Gonçalves
# -   #### Élen Silva Almeida
# -   #### Gabriel Matina
# -   #### Gustavo Dell Anhol Oliveira
# -   #### Patrick Kwan

# %% [markdown]
# ## Descrição do problema🤔
#
# Uma posição _volátil_, no futebol (tanto no Brasil quanto fora), é a posição de técnico. Uma prática comum é substituir o treinador após alguns resultados negativos. Naturalmente, um time que não troca o técnico não é garantia de sucesso no campeonato. Assim, surge a dúvida:
#
# <hr>
# <div style="text-align:center; font-size:20px">
# Será que, <b>em geral</b>, times com técnicos mais longevos ficam em uma posição melhor na tabela, no fim do campeonato?
# </div>
# <hr>

# %% [markdown]
# ## Manipulando os Dados🎲
#
# Para _atacar_ esse problema, será disponibilizado um arquivo json com todos os dados do Campeonato Brasileiro de 2019. Para ler um arquivo json, basta importar o módulo 'pandas' com o comando:  ```import pandas as pd```. Para ler um arquivo json, utilize o método:
# ```dados = pd.read_json('nome_do_arquivo.json') ```
#
# Para acessar os valores, basta olhar os nomes presentes nas linhas e colunas. Por exemplo:
#
# ```
# dados[2][1], sendo que:
# Primeiro índice -> Número da rodada
# Segundo índice  -> Número da partida
#
# ```
# Isso nos dá acesso a um dicionário com todas as informações da partida em questão, que nos permite acessar os valores utilizando as suas chaves.

# %%
#Nós importamos os dados utilizando a biblioteca Pandas para visualizarmos o arquivo json com a tabela
import pandas as pd

dados = pd.read_json('brasileirao-2019.json')
dados
# Out:
#                                                   1   \
# 0  {'clubs': {'home': 'São Paulo', 'away': 'Botaf...
# 1  {'clubs': {'home': 'Atlético-MG', 'away': 'Ava...
# 2  {'clubs': {'home': 'Chapecoense', 'away': 'Int...
# 3  {'clubs': {'home': 'Flamengo', 'away': 'Cruzei...
# 4  {'clubs': {'home': 'Grêmio', 'away': 'Santos'}...
# 5  {'clubs': {'home': 'Bahia', 'away': 'Corinthia...
# 6  {'clubs': {'home': 'Athletico-PR', 'away': 'Va...
# 7  {'clubs': {'home': 'Ceará SC', 'away': 'CSA'},...
# 8  {'clubs': {'home': 'Palmeiras', 'away': 'Forta...
# 9  {'clubs': {'home': 'Fluminense', 'away': 'Goiá...
#
#                                                   2   \
# 0  {'clubs': {'home': 'Internacional', 'away': 'F...
# 1  {'clubs': {'home': 'CSA', 'away': 'Palmeiras'}...
# 2  {'clubs': {'home': 'Corinthians', 'away': 'Cha...
# 3  {'clubs': {'home': 'Cruzeiro', 'away': 'Ceará ...
# 4  {'clubs': {'home': 'Avaí', 'away': 'Grêmio'}, ...
# 5  {'clubs': {'home': 'Goiás', 'away': 'São Paulo...
# 6  {'clubs': {'home': 'Vasco da Gama', 'away': 'A...
# 7  {'clubs': {'home': 'Fortaleza', 'away': 'Athle...
# 8  {'clubs': {'home': 'Santos', 'away': 'Fluminen...
# 9  {'clubs': {'home': 'Botafogo', 'away': 'Bahia'...
#
#                                                   3   \
# 0  {'clubs': {'home': 'Vasco da Gama', 'away': 'C...
# 1  {'clubs': {'home': 'Palmeiras', 'away': 'Inter...
# 2  {'clubs': {'home': 'Ceará SC', 'away': 'Atléti...
# 3  {'clubs': {'home': 'Chapecoense', 'away': 'Ath...
# 4  {'clubs': {'home': 'São Paulo', 'away': 'Flame...
# 5  {'clubs': {'home': 'Botafogo', 'away': 'Fortal...
# 6  {'clubs': {'home': 'CSA', 'away': 'Santos'}, '...
# 7  {'clubs': {'home': 'Cruzeiro', 'away': 'Goiás'...
# 8  {'clubs': {'home': 'Grêmio', 'away': 'Fluminen...
# 9  {'clubs': {'home': 'Bahia', 'away': 'Avaí'}, '...
#
#                                                   4   \
# 0  {'clubs': {'home': 'Fluminense', 'away': 'Bota...
# 1  {'clubs': {'home': 'Corinthians', 'away': 'Grê...
# 2  {'clubs': {'home': 'Goiás', 'away': 'Ceará SC'...
# 3  {'clubs': {'home': 'Flamengo', 'away': 'Chapec...
# 4  {'clubs': {'home': 'Santos', 'away': 'Vasco da...
# 5  {'clubs': {'home': 'Atlético-MG', 'away': 'Pal...
# 6  {'clubs': {'home': 'Internacional', 'away': 'C...
# 7  {'clubs': {'home': 'Avaí', 'away': 'CSA'}, 'go...
# 8  {'clubs': {'home': 'Athletico-PR', 'away': 'Ba...
# 9  {'clubs': {'home': 'Fortaleza', 'away': 'São P...
#
#                                                   5   \
# 0  {'clubs': {'home': 'Fluminense', 'away': 'Cruz...
# 1  {'clubs': {'home': 'Palmeiras', 'away': 'Santo...
# 2  {'clubs': {'home': 'Atlético-MG', 'away': 'Fla...
# 3  {'clubs': {'home': 'São Paulo', 'away': 'Bahia...
# 4  {'clubs': {'home': 'Internacional', 'away': 'C...
# 5  {'clubs': {'home': 'Athletico-PR', 'away': 'Co...
# 6  {'clubs': {'home': 'Goiás', 'away': 'Botafogo'...
# 7  {'clubs': {'home': 'Chapecoense', 'away': 'For...
# 8  {'clubs': {'home': 'Vasco da Gama', 'away': 'A...
# 9  {'clubs': {'home': 'Ceará SC', 'away': 'Grêmio...
#
#                                                   6   \
# 0  {'clubs': {'home': 'Botafogo', 'away': 'Palmei...
# 1  {'clubs': {'home': 'Grêmio', 'away': 'Atlético...
# 2  {'clubs': {'home': 'Flamengo', 'away': 'Athlet...
# 3  {'clubs': {'home': 'Santos', 'away': 'Internac...
# 4  {'clubs': {'home': 'Fortaleza', 'away': 'Vasco...
# 5  {'clubs': {'home': 'Cruzeiro', 'away': 'Chapec...
# 6  {'clubs': {'home': 'Bahia', 'away': 'Fluminens...
# 7  {'clubs': {'home': 'Corinthians', 'away': 'São...
# 8  {'clubs': {'home': 'CSA', 'away': 'Goiás'}, 'g...
# 9  {'clubs': {'home': 'Avaí', 'away': 'Ceará SC'}...
#
#                                                   7   \
# 0  {'clubs': {'home': 'Flamengo', 'away': 'Fortal...
# 1  {'clubs': {'home': 'Bahia', 'away': 'Grêmio'},...
# 2  {'clubs': {'home': 'Botafogo', 'away': 'Vasco ...
# 3  {'clubs': {'home': 'Ceará SC', 'away': 'Santos...
# 4  {'clubs': {'home': 'Athletico-PR', 'away': 'Fl...
# 5  {'clubs': {'home': 'São Paulo', 'away': 'Cruze...
# 6  {'clubs': {'home': 'Atlético-MG', 'away': 'CSA...
# 7  {'clubs': {'home': 'Chapecoense', 'away': 'Pal...
# 8  {'clubs': {'home': 'Internacional', 'away': 'A...
# 9  {'clubs': {'home': 'Corinthians', 'away': 'Goi...
#
#                                                   8   \
# 0  {'clubs': {'home': 'Vasco da Gama', 'away': 'I...
# 1  {'clubs': {'home': 'Palmeiras', 'away': 'Athle...
# 2  {'clubs': {'home': 'Grêmio', 'away': 'Fortalez...
# 3  {'clubs': {'home': 'Cruzeiro', 'away': 'Corint...
# 4  {'clubs': {'home': 'Ceará SC', 'away': 'Bahia'...
# 5  {'clubs': {'home': 'Avaí', 'away': 'São Paulo'...
# 6  {'clubs': {'home': 'CSA', 'away': 'Botafogo'},...
# 7  {'clubs': {'home': 'Fluminense', 'away': 'Flam...
# 8  {'clubs': {'home': 'Santos', 'away': 'Atlético...
# 9  {'clubs': {'home': 'Goiás', 'away': 'Chapecoen...
#
#                                                   9   \
# 0  {'clubs': {'home': 'Botafogo', 'away': 'Grêmio...
# 1  {'clubs': {'home': 'Fortaleza', 'away': 'Cruze...
# 2  {'clubs': {'home': 'Internacional', 'away': 'B...
# 3  {'clubs': {'home': 'CSA', 'away': 'Flamengo'},...
# 4  {'clubs': {'home': 'Santos', 'away': 'Corinthi...
# 5  {'clubs': {'home': 'Vasco da Gama', 'away': 'C...
# 6  {'clubs': {'home': 'Chapecoense', 'away': 'Flu...
# 7  {'clubs': {'home': 'Palmeiras', 'away': 'Avaí'...
# 8  {'clubs': {'home': 'Atlético-MG', 'away': 'São...
# 9  {'clubs': {'home': 'Goiás', 'away': 'Athletico...
#
#                                                   10  ...  \
# 0  {'clubs': {'home': 'Grêmio', 'away': 'Vasco da...  ...
# 1  {'clubs': {'home': 'Fortaleza', 'away': 'Avaí'...  ...
# 2  {'clubs': {'home': 'Bahia', 'away': 'Santos'},...  ...
# 3  {'clubs': {'home': 'São Paulo', 'away': 'Palme...  ...
# 4  {'clubs': {'home': 'Flamengo', 'away': 'Goiás'...  ...
# 5  {'clubs': {'home': 'Corinthians', 'away': 'CSA...  ...
# 6  {'clubs': {'home': 'Athletico-PR', 'away': 'In...  ...
# 7  {'clubs': {'home': 'Cruzeiro', 'away': 'Botafo...  ...
# 8  {'clubs': {'home': 'Chapecoense', 'away': 'Atl...  ...
# 9  {'clubs': {'home': 'Fluminense', 'away': 'Cear...  ...
#
#                                                   29  \
# 0  {'clubs': {'home': 'Palmeiras', 'away': 'São P...
# 1  {'clubs': {'home': 'Avaí', 'away': 'Fortaleza'...
# 2  {'clubs': {'home': 'Atlético-MG', 'away': 'Cha...
# 3  {'clubs': {'home': 'Ceará SC', 'away': 'Flumin...
# 4  {'clubs': {'home': 'Vasco da Gama', 'away': 'G...
# 5  {'clubs': {'home': 'CSA', 'away': 'Corinthians...
# 6  {'clubs': {'home': 'Santos', 'away': 'Bahia'},...
# 7  {'clubs': {'home': 'Goiás', 'away': 'Flamengo'...
# 8  {'clubs': {'home': 'Internacional', 'away': 'A...
# 9  {'clubs': {'home': 'Botafogo', 'away': 'Cruzei...
#
#                                                   30  \
# 0  {'clubs': {'home': 'Fortaleza', 'away': 'Atlét...
# 1  {'clubs': {'home': 'Fluminense', 'away': 'Vasc...
# 2  {'clubs': {'home': 'Palmeiras', 'away': 'Ceará...
# 3  {'clubs': {'home': 'Chapecoense', 'away': 'São...
# 4  {'clubs': {'home': 'Flamengo', 'away': 'Corint...
# 5  {'clubs': {'home': 'Athletico-PR', 'away': 'CS...
# 6  {'clubs': {'home': 'Grêmio', 'away': 'Internac...
# 7  {'clubs': {'home': 'Santos', 'away': 'Botafogo...
# 8  {'clubs': {'home': 'Cruzeiro', 'away': 'Bahia'...
# 9  {'clubs': {'home': 'Goiás', 'away': 'Avaí'}, '...
#
#                                                   31  \
# 0  {'clubs': {'home': 'Corinthians', 'away': 'For...
# 1  {'clubs': {'home': 'Atlético-MG', 'away': 'Goi...
# 2  {'clubs': {'home': 'Avaí', 'away': 'Santos'}, ...
# 3  {'clubs': {'home': 'Athletico-PR', 'away': 'Cr...
# 4  {'clubs': {'home': 'Vasco da Gama', 'away': 'P...
# 5  {'clubs': {'home': 'Bahia', 'away': 'Chapecoen...
# 6  {'clubs': {'home': 'Ceará SC', 'away': 'Intern...
# 7  {'clubs': {'home': 'São Paulo', 'away': 'Flumi...
# 8  {'clubs': {'home': 'Botafogo', 'away': 'Flamen...
# 9  {'clubs': {'home': 'Grêmio', 'away': 'CSA'}, '...
#
#                                                   32  \
# 0  {'clubs': {'home': 'Goiás', 'away': 'Santos'},...
# 1  {'clubs': {'home': 'Palmeiras', 'away': 'Corin...
# 2  {'clubs': {'home': 'Internacional', 'away': 'F...
# 3  {'clubs': {'home': 'Cruzeiro', 'away': 'Atléti...
# 4  {'clubs': {'home': 'São Paulo', 'away': 'Athle...
# 5  {'clubs': {'home': 'Flamengo', 'away': 'Bahia'...
# 6  {'clubs': {'home': 'Chapecoense', 'away': 'Grê...
# 7  {'clubs': {'home': 'Fortaleza', 'away': 'Ceará...
# 8  {'clubs': {'home': 'CSA', 'away': 'Vasco da Ga...
# 9  {'clubs': {'home': 'Botafogo', 'away': 'Avaí'}...
#
#                                                   34  \
# 0  {'clubs': {'home': 'Flamengo', 'away': 'Vasco ...
# 1  {'clubs': {'home': 'Santos', 'away': 'Cruzeiro...
# 2  {'clubs': {'home': 'Palmeiras', 'away': 'Grêmi...
# 3  {'clubs': {'home': 'Atlético-MG', 'away': 'Ath...
# 4  {'clubs': {'home': 'Goiás', 'away': 'Bahia'}, ...
# 5  {'clubs': {'home': 'Botafogo', 'away': 'Corint...
# 6  {'clubs': {'home': 'Ceará SC', 'away': 'São Pa...
# 7  {'clubs': {'home': 'Internacional', 'away': 'F...
# 8  {'clubs': {'home': 'Avaí', 'away': 'Chapecoens...
# 9  {'clubs': {'home': 'CSA', 'away': 'Fluminense'...
#
#                                                   33  \
# 0  {'clubs': {'home': 'Santos', 'away': 'São Paul...
# 1  {'clubs': {'home': 'Fluminense', 'away': 'Atlé...
# 2  {'clubs': {'home': 'Grêmio', 'away': 'Flamengo...
# 3  {'clubs': {'home': 'Bahia', 'away': 'Palmeiras...
# 4  {'clubs': {'home': 'Chapecoense', 'away': 'Cea...
# 5  {'clubs': {'home': 'Athletico-PR', 'away': 'Bo...
# 6  {'clubs': {'home': 'Corinthians', 'away': 'Int...
# 7  {'clubs': {'home': 'Fortaleza', 'away': 'CSA'}...
# 8  {'clubs': {'home': 'Vasco da Gama', 'away': 'G...
# 9  {'clubs': {'home': 'Cruzeiro', 'away': 'Avaí'}...
#
#                                                   35  \
# 0  {'clubs': {'home': 'Internacional', 'away': 'G...
# 1  {'clubs': {'home': 'Chapecoense', 'away': 'Bot...
# 2  {'clubs': {'home': 'Bahia', 'away': 'Atlético-...
# 3  {'clubs': {'home': 'Athletico-PR', 'away': 'Gr...
# 4  {'clubs': {'home': 'Flamengo', 'away': 'Ceará ...
# 5  {'clubs': {'home': 'Corinthians', 'away': 'Ava...
# 6  {'clubs': {'home': 'Fluminense', 'away': 'Palm...
# 7  {'clubs': {'home': 'Fortaleza', 'away': 'Santo...
# 8  {'clubs': {'home': 'São Paulo', 'away': 'Vasco...
# 9  {'clubs': {'home': 'Cruzeiro', 'away': 'CSA'},...
#
#                                                   36  \
# 0  {'clubs': {'home': 'Botafogo', 'away': 'Intern...
# 1  {'clubs': {'home': 'Ceará SC', 'away': 'Athlet...
# 2  {'clubs': {'home': 'Avaí', 'away': 'Fluminense...
# 3  {'clubs': {'home': 'Palmeiras', 'away': 'Flame...
# 4  {'clubs': {'home': 'Goiás', 'away': 'Fortaleza...
# 5  {'clubs': {'home': 'CSA', 'away': 'Bahia'}, 'g...
# 6  {'clubs': {'home': 'Atlético-MG', 'away': 'Cor...
# 7  {'clubs': {'home': 'Santos', 'away': 'Chapecoe...
# 8  {'clubs': {'home': 'Grêmio', 'away': 'São Paul...
# 9  {'clubs': {'home': 'Vasco da Gama', 'away': 'C...
#
#                                                   37  \
# 0  {'clubs': {'home': 'Athletico-PR', 'away': 'Sa...
# 1  {'clubs': {'home': 'Ceará SC', 'away': 'Corint...
# 2  {'clubs': {'home': 'Atlético-MG', 'away': 'Bot...
# 3  {'clubs': {'home': 'Chapecoense', 'away': 'CSA...
# 4  {'clubs': {'home': 'Fluminense', 'away': 'Fort...
# 5  {'clubs': {'home': 'São Paulo', 'away': 'Inter...
# 6  {'clubs': {'home': 'Grêmio', 'away': 'Cruzeiro...
# 7  {'clubs': {'home': 'Palmeiras', 'away': 'Goiás...
# 8  {'clubs': {'home': 'Bahia', 'away': 'Vasco da ...
# 9  {'clubs': {'home': 'Flamengo', 'away': 'Avaí'}...
#
#                                                   38
# 0  {'clubs': {'home': 'Corinthians', 'away': 'Flu...
# 1  {'clubs': {'home': 'Santos', 'away': 'Flamengo...
# 2  {'clubs': {'home': 'Botafogo', 'away': 'Ceará ...
# 3  {'clubs': {'home': 'CSA', 'away': 'São Paulo'}...
# 4  {'clubs': {'home': 'Internacional', 'away': 'A...
# 5  {'clubs': {'home': 'Cruzeiro', 'away': 'Palmei...
# 6  {'clubs': {'home': 'Goiás', 'away': 'Grêmio'},...
# 7  {'clubs': {'home': 'Vasco da Gama', 'away': 'C...
# 8  {'clubs': {'home': 'Avaí', 'away': 'Athletico-...
# 9  {'clubs': {'home': 'Fortaleza', 'away': 'Bahia...
#
# [10 rows x 38 columns]

# %% [markdown]
# ## Tratamento dos dados📝:
#
# Para começar a nossa análise primeiro começamos a tratar os dados que nos foram fornecidos. Para obter a resposta, precisamos dos seguintes dados:
#
# #### Em relação as partidas
# - Uma lista com o nome de todos os Treinadores
# - Uma lista com o nome de todos os times
#
# #### Em relação aos times
# - As pontuações e demais estatísticas da partida
# - A sua classificação baseada na pontuação
# - Todos os técnicos que passaram pelo time, e a quantidade de jogos em que atuaram com os mesmos
# - Qual foi o técnico que mais atuou em cada time e a quantidade de jogos

# %% [markdown]
# ---

# %% [markdown]
# #### Encontrando os técnicos
#
# Para consultarmos o técnico de um determinado time, podemos acessar o dataframe da seguinte forma:
# ```
# dados[número da rodada][número do jogo]['coach']
# (O índice 'coach' é uma chave do dicionário de informações presente na célula em questão)
# ```
# Com isso, podemos criar uma lista com todos os técnicos

# %%
#Criamos uma lista para armazenar o nome de todos os treinadores do campeonato
lista_tecnicos = []

#Este for irá percorrer todos os dados e ir armazenando os treinadores com base nas partidas jogadas
for rodada in dados: #1 ao 38
    for jogo in range(len(dados[rodada])): #1 ao 10
        lista_tecnicos.append(dados[rodada][jogo]['coach']['home'])
        lista_tecnicos.append(dados[rodada][jogo]['coach']['away'])

lista_tecnicos = list(set(lista_tecnicos)) #Elimina as duplicas utilizando o set
lista_tecnicos
# Out:
# ['M. Salles',
#  'R. L. Martins Gomes',
#  'C. dos Santos Oliveira',
#  'R. Colbachini',
#  'B. Lazaroni',
#  'M. de Oliveira',
#  'R. Ceni',
#  'A. Fucks',
#  'E. Machado Souto',
#  'J. Pires de Deus',
#  'E. Alves Moreira',
#  'E. Hartkopp',
#  'A. Batista',
#  'N. da Silveira Júnior',
#  'M. dos Santos Gonçalves',
#  'V. Luxemburgo da Silva',
#  'O. de Oliveira Filho',
#  'C. A. P. F. Hembert',
#  'L. Venker de Menezes',
#  'M. Gomes Valadares',
#  'E. de Barros',
#  'A. Valentim do Carmo Neto',
#  'M. Longo de Araújo',
#  'M. Ribeiro Cabo',
#  'R. Alves Resende',
#  'A. Stival',
#  'J. Mannarino',
#  'V. Carmo Mancini',
#  'F. Diniz Silva',
#  'E. Spinassé Camillato',
#  'Renato Gaúcho',
#  'Coelho',
#  'T. Retzalff Nunes',
#  'F. Carille',
#  'R. Marques Santana',
#  'A. da Silva Braga',
#  'A. Lopes dos Santos',
#  'E. de Souza Barroca',
#  'G. Santos Vasconcelo',
#  'J. Pinheiro de Jesus',
#  'M. Montenegro',
#  'L. Scolari',
#  'O. Hellmann',
#  'J. Sampaoli Moya',
#  'R. Machado Marques']

# %% [markdown]
# #### Encontrando os times
#
# Com isso, da mesma forma, também podemos criar uma lista com todos os times.
#
# Também se atentamos em selecionar todos os nomes dentro das chaves 'home' e 'away'(que representam times que jogaram em casa e fora respectivamente), para ter certeza de que nenhum nome ficaria de fora

# %%
# Lista com o nome de todos os times
lista_times = []

for rodada in dados: #1 ao 38
    for jogo in range(len(dados[rodada])): #1 ao 10
        lista_times.append(dados[rodada][jogo]['clubs']['home'])
        lista_times.append(dados[rodada][jogo]['clubs']['away'])

lista_times = list(set(lista_times)) #Elimina as duplicas utilizando o set
lista_times
# Out:
# ['Cruzeiro',
#  'Fortaleza',
#  'São Paulo',
#  'Ceará SC',
#  'Flamengo',
#  'Santos',
#  'CSA',
#  'Grêmio',
#  'Palmeiras',
#  'Vasco da Gama',
#  'Botafogo',
#  'Bahia',
#  'Avaí',
#  'Fluminense',
#  'Atlético-MG',
#  'Goiás',
#  'Corinthians',
#  'Internacional',
#  'Chapecoense',
#  'Athletico-PR']

# %% [markdown]
# E com essa informação, conseguimos criar uma estrutura de dados para relacionar o nome do time, os técnicos e todos os jogos que os mesmos atuaram entre si

# %%
# Para armazenarmos a quantidade de jogos que um treinador teve para os respectivos clubes que ele treinou, criamos uma nova variável
partidas = {}

# Este for cria um dicionário com o nome de cada um dos times, os seus respectivos treinadores e 
# quantas partidas o treinador atuou pelo time (inicialmente 0) 
for coach in lista_tecnicos:
    for time in lista_times:
        partidas[time] = {coach : 0 for coach in lista_tecnicos}
        
for coach in lista_tecnicos:
    for time in lista_times:
        partidas[time][coach] = 0

# Aqui preenchemos a quantidade de vezes que o técnico treinou o time
for rodada in dados: #1 ao 38
    for jogo in range(len(dados[rodada])): #0 ao 9
        time_casa = dados[rodada][jogo]['clubs']['home']
        coach_casa = dados[rodada][jogo]['coach']['home']
        
        time_fora = dados[rodada][jogo]['clubs']['away']
        coach_fora = dados[rodada][jogo]['coach']['away']
        
        partidas[time_casa][coach_casa] += 1
        partidas[time_fora][coach_fora] += 1
        
partidas
# Out:
# {'Cruzeiro': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 7,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 3,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 13,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 1,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 14,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Fortaleza': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 29,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 1,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 7,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 1,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'São Paulo': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 1,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 21,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 16,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Ceará SC': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 3,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 22,
#   'E. Hartkopp': 0,
#   'A. Batista': 13,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Flamengo': {'M. Salles': 3,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 1,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 6,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 28,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Santos': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 38,
#   'R. Machado Marques': 0},
#  'CSA': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 26,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 9,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 3,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Grêmio': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 38,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Palmeiras': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 20,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 2,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 16,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Vasco da Gama': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 34,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 4,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Botafogo': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 2,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 13,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 23,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Bahia': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 38},
#  'Avaí': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 9,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 15,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 14,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Fluminense': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 17,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 6,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 15,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Atlético-MG': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 13,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 25,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Goiás': {'M. Salles': 0,
#   'R. L. Martins Gomes': 1,
#   'C. dos Santos Oliveira': 12,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 25,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Corinthians': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 8,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 30,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Internacional': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 3,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 11,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 24,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Chapecoense': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 8,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 11,
#   'M. dos Santos Gonçalves': 19,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 0,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 0,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0},
#  'Athletico-PR': {'M. Salles': 0,
#   'R. L. Martins Gomes': 0,
#   'C. dos Santos Oliveira': 0,
#   'R. Colbachini': 0,
#   'B. Lazaroni': 0,
#   'M. de Oliveira': 0,
#   'R. Ceni': 0,
#   'A. Fucks': 0,
#   'E. Machado Souto': 0,
#   'J. Pires de Deus': 0,
#   'E. Alves Moreira': 0,
#   'E. Hartkopp': 0,
#   'A. Batista': 0,
#   'N. da Silveira Júnior': 0,
#   'M. dos Santos Gonçalves': 0,
#   'V. Luxemburgo da Silva': 0,
#   'O. de Oliveira Filho': 0,
#   'C. A. P. F. Hembert': 0,
#   'L. Venker de Menezes': 0,
#   'M. Gomes Valadares': 0,
#   'E. de Barros': 8,
#   'A. Valentim do Carmo Neto': 0,
#   'M. Longo de Araújo': 0,
#   'M. Ribeiro Cabo': 0,
#   'R. Alves Resende': 0,
#   'A. Stival': 0,
#   'J. Mannarino': 0,
#   'V. Carmo Mancini': 0,
#   'F. Diniz Silva': 0,
#   'E. Spinassé Camillato': 0,
#   'Renato Gaúcho': 0,
#   'Coelho': 0,
#   'T. Retzalff Nunes': 30,
#   'F. Carille': 0,
#   'R. Marques Santana': 0,
#   'A. da Silva Braga': 0,
#   'A. Lopes dos Santos': 0,
#   'E. de Souza Barroca': 0,
#   'G. Santos Vasconcelo': 0,
#   'J. Pinheiro de Jesus': 0,
#   'M. Montenegro': 0,
#   'L. Scolari': 0,
#   'O. Hellmann': 0,
#   'J. Sampaoli Moya': 0,
#   'R. Machado Marques': 0}}

# %% [markdown]
# Com o dicionário ```partidas``` preenchido, filtramos os técnicos, deixando somente os mais longevos de cada time

# %%
mais_longevo = {}

for time in lista_times:
    partida_mais_longeva = 0
    mais_longevo[time] = {}  
    for coach in lista_tecnicos:
        if partidas[time][coach] > partida_mais_longeva:
            partida_mais_longeva = partidas[time][coach]
            mais_longevo[time] = {coach: partida_mais_longeva}
mais_longevo
# Out:
# {'Cruzeiro': {'A. da Silva Braga': 14},
#  'Fortaleza': {'R. Ceni': 29},
#  'São Paulo': {'A. Stival': 21},
#  'Ceará SC': {'E. Alves Moreira': 22},
#  'Flamengo': {'J. Pinheiro de Jesus': 28},
#  'Santos': {'J. Sampaoli Moya': 38},
#  'CSA': {'A. Fucks': 26},
#  'Grêmio': {'Renato Gaúcho': 38},
#  'Palmeiras': {'L. Venker de Menezes': 20},
#  'Vasco da Gama': {'V. Luxemburgo da Silva': 34},
#  'Botafogo': {'E. de Souza Barroca': 23},
#  'Bahia': {'R. Machado Marques': 38},
#  'Avaí': {'A. Valentim do Carmo Neto': 15},
#  'Fluminense': {'M. de Oliveira': 17},
#  'Atlético-MG': {'R. Marques Santana': 25},
#  'Goiás': {'N. da Silveira Júnior': 25},
#  'Corinthians': {'F. Carille': 30},
#  'Internacional': {'O. Hellmann': 24},
#  'Chapecoense': {'M. dos Santos Gonçalves': 19},
#  'Athletico-PR': {'T. Retzalff Nunes': 30}}

# %% [markdown]
# Também precisamos das pontuações do time para definirmos a classificação, com isso criamos uma outra estrutura de dados chamada ```tabela_times``` que apenas extrai os respectivos dados do dataframe e os armazena

# %%
tabela_times = {}

for i in lista_times:
    tabela_times[i] = {'Jogos': 0,  # Qtde de jogos
                       'PTS': 0,    # Qtde de pontos totais
                       'VIT': 0,    # Qtde de vitórias
                       'EMP': 0,    # Qtde de empates
                       'DER': 0,    # Qtde de derrotas
                       'GM': 0,     # Qtde de gols marcados
                       'GC': 0,     # Qtde de gols contra (sofridos)
                       'SG': 0}     # Saldo de Gols

for rodada in dados: #1 ao 38
    for jogo in range(len(dados[rodada])): #0 ao 9
        
        time_casa = dados[rodada][jogo]['clubs']['home']
        time_fora = dados[rodada][jogo]['clubs']['away']
        
        golcasa = int(dados[rodada][jogo]["goals"]["home"])
        golfora = int(dados[rodada][jogo]["goals"]["away"])

        if golcasa > golfora:
            #REFERENTE AO TIME DA CASA:
            tabela_times[time_casa]["PTS"] += 3
            tabela_times[time_casa]["VIT"] += 1
            tabela_times[time_casa]["Jogos"] += 1
            tabela_times[time_casa]["GM"] += golcasa 
            tabela_times[time_casa]["GC"] += golfora
            tabela_times[time_casa]["SG"] += golcasa - golfora
            
            #REFERENTE AO TIME FORA
            tabela_times[time_fora]["DER"] += 1
            tabela_times[time_fora]["Jogos"] += 1
            tabela_times[time_fora]["GM"] += golfora 
            tabela_times[time_fora]["GC"] += golcasa
            tabela_times[time_fora]["SG"] += golfora - golcasa
            
        elif golcasa < golfora:
            #REFERENTE AO TIME FORA:
            tabela_times[time_fora]["PTS"] += 3
            tabela_times[time_fora]["VIT"] += 1
            tabela_times[time_fora]["Jogos"] += 1
            tabela_times[time_fora]["GM"] += golfora
            tabela_times[time_fora]["GC"] += golcasa
            tabela_times[time_fora]["SG"] += golfora - golcasa
            
            #REFERENTE AO TIME CASA
            tabela_times[time_casa]["DER"] += 1
            tabela_times[time_casa]["Jogos"] += 1
            tabela_times[time_casa]["GM"] += golcasa 
            tabela_times[time_casa]["GC"] += golfora
            tabela_times[time_casa]["SG"] += golcasa - golfora
            
        else:
            #REFERENTE AO TIME DA CASA:
            tabela_times[time_casa]["PTS"] += 1
            tabela_times[time_casa]['EMP'] += 1
            tabela_times[time_casa]["Jogos"] += 1
            tabela_times[time_casa]["GM"] += golcasa 
            tabela_times[time_casa]["GC"] += golfora
            tabela_times[time_casa]["SG"] += golcasa - golfora
            
            #REFERENTE AO TIME FORA
            tabela_times[time_fora]["PTS"] += 1
            tabela_times[time_fora]['EMP'] += 1
            tabela_times[time_fora]["Jogos"] += 1
            tabela_times[time_fora]["GM"] += golfora 
            tabela_times[time_fora]["GC"] += golcasa
            tabela_times[time_fora]["SG"] += golfora - golcasa

tabela_times
# Out:
# {'Cruzeiro': {'Jogos': 38,
#   'PTS': 36,
#   'VIT': 7,
#   'EMP': 15,
#   'DER': 16,
#   'GM': 27,
#   'GC': 46,
#   'SG': -19},
#  'Fortaleza': {'Jogos': 38,
#   'PTS': 53,
#   'VIT': 15,
#   'EMP': 8,
#   'DER': 15,
#   'GM': 50,
#   'GC': 49,
#   'SG': 1},
#  'São Paulo': {'Jogos': 38,
#   'PTS': 63,
#   'VIT': 17,
#   'EMP': 12,
#   'DER': 9,
#   'GM': 39,
#   'GC': 30,
#   'SG': 9},
#  'Ceará SC': {'Jogos': 38,
#   'PTS': 39,
#   'VIT': 10,
#   'EMP': 9,
#   'DER': 19,
#   'GM': 36,
#   'GC': 41,
#   'SG': -5},
#  'Flamengo': {'Jogos': 38,
#   'PTS': 90,
#   'VIT': 28,
#   'EMP': 6,
#   'DER': 4,
#   'GM': 86,
#   'GC': 37,
#   'SG': 49},
#  'Santos': {'Jogos': 38,
#   'PTS': 74,
#   'VIT': 22,
#   'EMP': 8,
#   'DER': 8,
#   'GM': 60,
#   'GC': 33,
#   'SG': 27},
#  'CSA': {'Jogos': 38,
#   'PTS': 32,
#   'VIT': 8,
#   'EMP': 8,
#   'DER': 22,
#   'GM': 24,
#   'GC': 58,
#   'SG': -34},
#  'Grêmio': {'Jogos': 38,
#   'PTS': 65,
#   'VIT': 19,
#   'EMP': 8,
#   'DER': 11,
#   'GM': 64,
#   'GC': 39,
#   'SG': 25},
#  'Palmeiras': {'Jogos': 38,
#   'PTS': 74,
#   'VIT': 21,
#   'EMP': 11,
#   'DER': 6,
#   'GM': 61,
#   'GC': 32,
#   'SG': 29},
#  'Vasco da Gama': {'Jogos': 38,
#   'PTS': 49,
#   'VIT': 12,
#   'EMP': 13,
#   'DER': 13,
#   'GM': 39,
#   'GC': 45,
#   'SG': -6},
#  'Botafogo': {'Jogos': 38,
#   'PTS': 43,
#   'VIT': 13,
#   'EMP': 4,
#   'DER': 21,
#   'GM': 31,
#   'GC': 45,
#   'SG': -14},
#  'Bahia': {'Jogos': 38,
#   'PTS': 49,
#   'VIT': 12,
#   'EMP': 13,
#   'DER': 13,
#   'GM': 44,
#   'GC': 43,
#   'SG': 1},
#  'Avaí': {'Jogos': 38,
#   'PTS': 20,
#   'VIT': 3,
#   'EMP': 11,
#   'DER': 24,
#   'GM': 18,
#   'GC': 62,
#   'SG': -44},
#  'Fluminense': {'Jogos': 38,
#   'PTS': 46,
#   'VIT': 12,
#   'EMP': 10,
#   'DER': 16,
#   'GM': 38,
#   'GC': 46,
#   'SG': -8},
#  'Atlético-MG': {'Jogos': 38,
#   'PTS': 48,
#   'VIT': 13,
#   'EMP': 9,
#   'DER': 16,
#   'GM': 45,
#   'GC': 49,
#   'SG': -4},
#  'Goiás': {'Jogos': 38,
#   'PTS': 52,
#   'VIT': 15,
#   'EMP': 7,
#   'DER': 16,
#   'GM': 46,
#   'GC': 64,
#   'SG': -18},
#  'Corinthians': {'Jogos': 38,
#   'PTS': 56,
#   'VIT': 14,
#   'EMP': 14,
#   'DER': 10,
#   'GM': 42,
#   'GC': 34,
#   'SG': 8},
#  'Internacional': {'Jogos': 38,
#   'PTS': 57,
#   'VIT': 16,
#   'EMP': 9,
#   'DER': 13,
#   'GM': 44,
#   'GC': 39,
#   'SG': 5},
#  'Chapecoense': {'Jogos': 38,
#   'PTS': 32,
#   'VIT': 7,
#   'EMP': 11,
#   'DER': 20,
#   'GM': 31,
#   'GC': 52,
#   'SG': -21},
#  'Athletico-PR': {'Jogos': 38,
#   'PTS': 64,
#   'VIT': 18,
#   'EMP': 10,
#   'DER': 10,
#   'GM': 51,
#   'GC': 32,
#   'SG': 19}}

# %% [markdown]
# Com a pontuação definida, criamos a lista ```classificacao``` para definir a classificação dos times no campeonato utilizando o algoritimo de ordenação ```Bubble Sort``` para ordenar a lista do menor para o maior baseado em suas pontuações

# %%
classificacao = [['Time','Pontos','Vitórias','Empates','Derrotas','Gols Marcados','Gols Sofridos','Saldo de Gols']]

for time in tabela_times:
    classificacao.append([time, tabela_times[time]['PTS'], tabela_times[time]['VIT'], tabela_times[time]['EMP'], tabela_times[time]['DER'],tabela_times[time]['GM'],tabela_times[time]['GC'],tabela_times[time]['SG']])
    
# Dentro da tupla
# 0 - Time              (nome)
# 1 - Pontos            (PTS)
# 2 - Vitórias          (VIT)
# 3 - Empates           (EMP)
# 4 - Derrotas          (DER)
# 5 - Gols marcados     (GM)
# 6 - Gols Sofridos     (GC)
# 7 - Saldo de gols     (SG)

# 
for i in range(1, len(classificacao)):
    for j in range(1, len(classificacao) - i):
        if classificacao[j][1] < classificacao[j + 1][1]:
            classificacao[j], classificacao[j + 1] = classificacao[j + 1], classificacao[j]

classificacao = list(enumerate(classificacao))
classificacao
# Out:
# [(0,
#   ['Time',
#    'Pontos',
#    'Vitórias',
#    'Empates',
#    'Derrotas',
#    'Gols Marcados',
#    'Gols Sofridos',
#    'Saldo de Gols']),
#  (1, ['Flamengo', 90, 28, 6, 4, 86, 37, 49]),
#  (2, ['Santos', 74, 22, 8, 8, 60, 33, 27]),
#  (3, ['Palmeiras', 74, 21, 11, 6, 61, 32, 29]),
#  (4, ['Grêmio', 65, 19, 8, 11, 64, 39, 25]),
#  (5, ['Athletico-PR', 64, 18, 10, 10, 51, 32, 19]),
#  (6, ['São Paulo', 63, 17, 12, 9, 39, 30, 9]),
#  (7, ['Internacional', 57, 16, 9, 13, 44, 39, 5]),
#  (8, ['Corinthians', 56, 14, 14, 10, 42, 34, 8]),
#  (9, ['Fortaleza', 53, 15, 8, 15, 50, 49, 1]),
#  (10, ['Goiás', 52, 15, 7, 16, 46, 64, -18]),
#  (11, ['Vasco da Gama', 49, 12, 13, 13, 39, 45, -6]),
#  (12, ['Bahia', 49, 12, 13, 13, 44, 43, 1]),
#  (13, ['Atlético-MG', 48, 13, 9, 16, 45, 49, -4]),
#  (14, ['Fluminense', 46, 12, 10, 16, 38, 46, -8]),
#  (15, ['Botafogo', 43, 13, 4, 21, 31, 45, -14]),
#  (16, ['Ceará SC', 39, 10, 9, 19, 36, 41, -5]),
#  (17, ['Cruzeiro', 36, 7, 15, 16, 27, 46, -19]),
#  (18, ['CSA', 32, 8, 8, 22, 24, 58, -34]),
#  (19, ['Chapecoense', 32, 7, 11, 20, 31, 52, -21]),
#  (20, ['Avaí', 20, 3, 11, 24, 18, 62, -44])]

# %% [markdown]
# No final observamos que houveram algumas situações de empates:
# ```
# Empates em pontuação:
# Santos e Palmeiras        74pts
# Vasco da Gama e Bahia     49pts
# Chapecoense e CSA         32pts
#
# ```
# Neste caso o Vasco da Gama ficou antes do Bahia e o Chapecoense ficou antes do CSA. Se analisarmos a classificação do Brasileirão de 2019 na internet, notamos que essa ordem é inversa, por conta do critério de desempate utilizado no campeonato, que resumido se baseia em:
#
# - Maior quantidade de vitórias
# - Maior saldo de gols
# - Maior quantidade de gols marcados
#
# Então, de volta ao ```Bubble Sort```, aplicamos os critérios de desmpate e reordenamos a lista

# %%
# Critérios de desempate (NESTA ORDEM) 
#   Maior quantidade de vitórias        indice[2]
#   Maior saldo de gols                 indice[7]
#   Maior quantidade de gols marcados   indice[5]

for i in range(1, len(classificacao)):
    for j in range(1, len(classificacao) - i):
        if (classificacao[j][1] == classificacao[j + 1][1]):
            
            # Verifica se a Quantidade de vitórias é igual ou menor
            if (classificacao[j][2] < classificacao[j + 1][2]):
                classificacao[j], classificacao[j + 1] = classificacao[j + 1], classificacao[j]
            
            #Se a vitoria for igual, muda o criterio de desempate:
            elif (classificacao[j][2] == classificacao[j + 1][2]):
                # Se a quantidade do 'Saldo de gols' do item j for menor do que o próximo item
                if classificacao[j][7] < classificacao[j + 1][7]:
                    classificacao[j], classificacao[j + 1] = classificacao[j + 1], classificacao[j]

                # Se empatar no saldo de gols, verificar gols marcados
                elif classificacao[j][7] == classificacao[j + 1][7]:
                    # Se a quantidade de gols marcados do item j for menor do que o próximo item
                    if classificacao[j][5] < classificacao[j + 1][5]:
                        classificacao[j], classificacao[j + 1] = classificacao[j + 1], classificacao[j]

# %% [markdown]
# Com isso temos a classificação final do campeonato com as respectivas pontuações

# %%
dados_impressao = [(item[0], item[1]) for item in classificacao]
for row in dados_impressao:
    print(f"{row[0]:<3} | {row[1][0]:<15} | {row[1][1]:<10} | {row[1][2]:<10} | {row[1][3]:<10} | {row[1][4]:<10} | {row[1][5]:<15} | {row[1][6]:<15} | {row[1][7]}")
# Out:
# 0   | Time            | Pontos     | Vitórias   | Empates    | Derrotas   | Gols Marcados   | Gols Sofridos   | Saldo de Gols
# 1   | Flamengo        | 90         | 28         | 6          | 4          | 86              | 37              | 49
# 2   | Santos          | 74         | 22         | 8          | 8          | 60              | 33              | 27
# 3   | Palmeiras       | 74         | 21         | 11         | 6          | 61              | 32              | 29
# 4   | Grêmio          | 65         | 19         | 8          | 11         | 64              | 39              | 25
# 5   | Athletico-PR    | 64         | 18         | 10         | 10         | 51              | 32              | 19
# 6   | São Paulo       | 63         | 17         | 12         | 9          | 39              | 30              | 9
# 7   | Internacional   | 57         | 16         | 9          | 13         | 44              | 39              | 5
# 8   | Corinthians     | 56         | 14         | 14         | 10         | 42              | 34              | 8
# 9   | Fortaleza       | 53         | 15         | 8          | 15         | 50              | 49              | 1
# 10  | Goiás           | 52         | 15         | 7          | 16         | 46              | 64              | -18
# 11  | Vasco da Gama   | 49         | 12         | 13         | 13         | 39              | 45              | -6
# 12  | Bahia           | 49         | 12         | 13         | 13         | 44              | 43              | 1
# 13  | Atlético-MG     | 48         | 13         | 9          | 16         | 45              | 49              | -4
# 14  | Fluminense      | 46         | 12         | 10         | 16         | 38              | 46              | -8
# 15  | Botafogo        | 43         | 13         | 4          | 21         | 31              | 45              | -14
# 16  | Ceará SC        | 39         | 10         | 9          | 19         | 36              | 41              | -5
# 17  | Cruzeiro        | 36         | 7          | 15         | 16         | 27              | 46              | -19
# 18  | CSA             | 32         | 8          | 8          | 22         | 24              | 58              | -34
# 19  | Chapecoense     | 32         | 7          | 11         | 20         | 31              | 52              | -21
# 20  | Avaí            | 20         | 3          | 11         | 24         | 18              | 62              | -44

# %% [markdown]
# E utilizando as informações tratadas anteriormente, também conseguimos visualizar os times em ordem de classificação por pontos e seus respectivos técnicos mais longevos com a quantidade de partidas que o mesmo atuou no time

# %%
class_tecnico_longevo = []
tecnicos = list(mais_longevo.values())
for i in range(1, len(classificacao)):
    for chave, valor in mais_longevo.items():
        for treinador in valor.keys():
            if classificacao[i][1][0] == chave:
                print(f"Colocação:{classificacao[i][0]:2d} | {classificacao[i][1][0]:<15} | Técnico mais longevo:   {treinador:<28} | Qtde de partidas: {mais_longevo[chave][treinador]}")
# Out:
# Colocação: 1 | Flamengo        | Técnico mais longevo:   J. Pinheiro de Jesus         | Qtde de partidas: 28
# Colocação: 2 | Santos          | Técnico mais longevo:   J. Sampaoli Moya             | Qtde de partidas: 38
# Colocação: 3 | Palmeiras       | Técnico mais longevo:   L. Venker de Menezes         | Qtde de partidas: 20
# Colocação: 4 | Grêmio          | Técnico mais longevo:   Renato Gaúcho                | Qtde de partidas: 38
# Colocação: 5 | Athletico-PR    | Técnico mais longevo:   T. Retzalff Nunes            | Qtde de partidas: 30
# Colocação: 6 | São Paulo       | Técnico mais longevo:   A. Stival                    | Qtde de partidas: 21
# Colocação: 7 | Internacional   | Técnico mais longevo:   O. Hellmann                  | Qtde de partidas: 24
# Colocação: 8 | Corinthians     | Técnico mais longevo:   F. Carille                   | Qtde de partidas: 30
# Colocação: 9 | Fortaleza       | Técnico mais longevo:   R. Ceni                      | Qtde de partidas: 29
# Colocação:10 | Goiás           | Técnico mais longevo:   N. da Silveira Júnior        | Qtde de partidas: 25
# Colocação:11 | Vasco da Gama   | Técnico mais longevo:   V. Luxemburgo da Silva       | Qtde de partidas: 34
# Colocação:12 | Bahia           | Técnico mais longevo:   R. Machado Marques           | Qtde de partidas: 38
# Colocação:13 | Atlético-MG     | Técnico mais longevo:   R. Marques Santana           | Qtde de partidas: 25
# Colocação:14 | Fluminense      | Técnico mais longevo:   M. de Oliveira               | Qtde de partidas: 17
# Colocação:15 | Botafogo        | Técnico mais longevo:   E. de Souza Barroca          | Qtde de partidas: 23
# Colocação:16 | Ceará SC        | Técnico mais longevo:   E. Alves Moreira             | Qtde de partidas: 22
# Colocação:17 | Cruzeiro        | Técnico mais longevo:   A. da Silva Braga            | Qtde de partidas: 14
# Colocação:18 | CSA             | Técnico mais longevo:   A. Fucks                     | Qtde de partidas: 26
# Colocação:19 | Chapecoense     | Técnico mais longevo:   M. dos Santos Gonçalves      | Qtde de partidas: 19
# Colocação:20 | Avaí            | Técnico mais longevo:   A. Valentim do Carmo Neto    | Qtde de partidas: 15

# %% [markdown]
# Com as classificações e a quantidade de partidas que o técnico mais longevo atuo no time que fiocu na determinada classificação, podemos relacionar esses dados em um grafico de linhas para observar se há alguma relação entre a longevidade dos técnicos nos times e sua classificação

# %%
# classificacao[x][1][0]      Acessa os nomes dos times
# classificacao[1][0]         Acessa a classificação dos times

import matplotlib.pyplot as plt

dados_plotagem = []
dados_plotagem_x = []
dados_plotagem_y = []

for i in range(1, len(classificacao)):
    nome_time = classificacao[i][1][0]
    tec_mais_longevo = list(mais_longevo[nome_time].items())
    dados_plotagem.append((classificacao[i][0], tec_mais_longevo[0][1]))
    
for x, y in dados_plotagem:    
    dados_plotagem_x.append(x)
    dados_plotagem_y.append(y)

plt.figure(figsize=(8,6))
plt.title('Campeonato Brasileiro 2019')

plt.scatter(dados_plotagem_x, dados_plotagem_y)
plt.xlabel('Posição')
plt.ylabel('Técnico mais longevo (rodadas)')
plt.xscale('linear')

plt.xticks(dados_plotagem_x)
plt.yticks(dados_plotagem_y)
plt.plot(dados_plotagem_x, dados_plotagem_y, linestyle='--', marker='o', color='red', label='Linha de Conexão')
plt.show()

# %% [markdown]
# ## RECAPITULANDO
#
# Precisávamos responder a seguinte pergunta:
# <div style="text-align:center; font-size:20px">
# Será que, <b>em geral</b>, times com técnicos mais longevos ficam em uma posição melhor na tabela, no fim do campeonato?
# </div>
# <br>
# Com isso em mente, e analisando o gráfico, podemos concluir que:
#
# - Mesmo times com técnicos pouco longevos, como o 3º lugar, conseguem se classificar bem no campeonato
# - O 1º lugar não teve o técnico mais longevo
# - O 12º lugar, mesmo com um dos técnicos mais longevos da campeonato, não teve uma colocação boa
# - De fato, alguns times com os técnicos menos longevos do campeonato ficaram nas últimas posições
#
# ### Conclusão
#
# Não é possível encontrar uma relação direta entre longevidade do técnico no time e sua classificação. Entendemos que, isso se dá por que futebol é um esporte extremamente estatístico e a qualidade de um time depende de inúmeras variáves e situações, no entanto, neste caso específico, podemos notar que os técnicos mais longevos das 10 melhores colocações jogaram pelo menos metade do campeonato, o que nos sugere que sim, a longevidade influencia positivamente, mas não é determinante para a colocação final do time
